# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input
# /kaggle/input/raw-890
# /kaggle/input/reference-890
# /kaggle/input/challenging-60

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
from torchvision.utils import save_image, make_grid
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import random
import os


print(torch.cuda.is_available())  # Should return True
print(torch.cuda.current_device())  # GPU index
print(torch.cuda.get_device_name(0))  # GPU name


# Directory paths
train_images_path = '/kaggle/input/raw-890'
train_cleaned_path = '/kaggle/input/reference-890'
test_images_path = '/kaggle/input/challenging-60'
save_cleaned_path = '/kaggle/working/cleanedTestImages'
model_save_path = '/kaggle/working/gan_model.pth'

def imshow(tensor, num_images=5):
    grid = make_grid(tensor[:num_images], nrow=num_images)
    plt.imshow(grid.permute(1, 2, 0).cpu().numpy())
    plt.axis('off')
    plt.show()

# Create save path for cleaned test images
os.makedirs(save_cleaned_path, exist_ok=True)
# Out:
# True
# 0
# Tesla P100-PCIE-16GB

# %%
class ApplyTransformations:
    def __init__(self, transform):
        self.transform = transform

    def __call__(self, input_image, target_filename):
        target_path = os.path.join(train_cleaned_path, target_filename)
        target_image = Image.open(target_path).convert("RGB")

        # Apply the same transformations to both input and target image
        seed = random.random()
        # Apply random transformations using the seed for reproducibility
        random.seed(seed)
        input_image = self.transform(input_image)
        
        random.seed(seed)
        target_image = self.transform(target_image)

        return input_image, target_image


# Define the transformations for training
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),        # Randomly flip the image horizontally
    transforms.RandomVerticalFlip(p=0.5),   
    transforms.RandomResizedCrop(size=(128, 128), scale=(0.8, 1.0)), 
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

apply_transform = ApplyTransformations(train_transform)

class ImageDataset(Dataset):
    def __init__(self, input_dir, target_dir=None, transform=None, augment_count=5, num_samples=None):
        self.input_dir = input_dir
        self.target_dir = target_dir
        self.transform = transform
        self.augment_count = augment_count  # Number of augmented versions per image
        
        # Get all files
        self.input_files = sorted(os.listdir(input_dir))
        
        if target_dir:
            self.target_files = sorted(os.listdir(target_dir))
        
        # Randomly sample 'num_samples' files if specified
        if num_samples:
            sampled_indices = random.sample(range(len(self.input_files)), num_samples)
            self.input_files = [self.input_files[i] for i in sampled_indices]
            if target_dir:
                self.target_files = [self.target_files[i] for i in sampled_indices]
    
    def __len__(self):
        # Multiply the length of the dataset by the augment_count to generate multiple versions per image
        return len(self.input_files) * self.augment_count

    def __getitem__(self, idx):
        # Get the original image index (using modulus to cycle through the images)
        orig_idx = idx % len(self.input_files)
        
        input_path = os.path.join(self.input_dir, self.input_files[orig_idx])
        input_image = Image.open(input_path).convert("RGB")
        
        if self.transform:
            if self.target_dir:
                input_image, target_image = self.transform(input_image, self.target_files[orig_idx])
                return input_image, target_image
            else:
                input_image = self.transform(input_image)
                return input_image
        
        


# Load data
train_dataset = ImageDataset(train_images_path, train_cleaned_path, transform=apply_transform, augment_count=3)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

test_dataset = ImageDataset(test_images_path, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# GAN Model
class ResidualBlock(nn.Module):
    def __init__(self, in_channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_channels),
        )
        
    def forward(self, x):
        return x + self.block(x)

class Generator(nn.Module):
    def __init__(self, num_residual_blocks=6):
        super(Generator, self).__init__()
        # Initial convolution
        self.initial = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=1, padding=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        # Downsampling
        self.downsample = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
        )
        # Residual blocks
        self.res_blocks = nn.Sequential(
            *[ResidualBlock(256) for _ in range(num_residual_blocks)]
        )
        # Upsampling
        self.upsample = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
        )
        # Final output
        self.final = nn.Sequential(
            nn.Conv2d(64, 3, kernel_size=7, stride=1, padding=3),
            nn.Tanh()
        )
        
    def forward(self, x):
        x = self.initial(x)
        x = self.downsample(x)
        x = self.res_blocks(x)
        x = self.upsample(x)
        return self.final(x)



class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.main(x).mean(dim=(2, 3)).squeeze(1)

# Initialize models
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Loss and Optimizers
criterion = nn.BCELoss()
optimizer_G = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=0.0005, betas=(0.5, 0.999))

# %%
# Training the GAN
epochs = 180
from tqdm import tqdm 
for epoch in range(epochs):
    progress_bar = tqdm(train_loader, desc=f"Epoch [{epoch+1}/{epochs}]", leave=False)
    
    for i, (inputs, targets) in enumerate(progress_bar):
        inputs, targets = inputs.to(device), targets.to(device)

        # Train Discriminator
        optimizer_D.zero_grad()
        real_labels = torch.ones(inputs.size(0), device=device)
        fake_labels = torch.zeros(inputs.size(0), device=device)


        outputs = discriminator(targets)
        real_loss = criterion(outputs, real_labels)
    
        fake_images = generator(inputs)
        outputs = discriminator(fake_images.detach())
        fake_loss = criterion(outputs, fake_labels)

        d_loss = (real_loss + fake_loss)
        d_loss.backward()
        optimizer_D.step()

        # Train Generator
        optimizer_G.zero_grad()
        outputs = discriminator(fake_images)
        g_loss = criterion(outputs, real_labels)
        g_loss.backward()
        optimizer_G.step()
        progress_bar.set_postfix({"D Loss": d_loss.item(), "G Loss": g_loss.item()})
        
    if (epoch + 1) % 10 == 0:  # Adjust this to visualize less frequently
        print(f"Epoch [{epoch + 1}/{epochs}], D Loss: {d_loss.item():.4f}, G Loss: {g_loss.item():.4f}")
        model_save_path = f'/kaggle/working/gan_model_{epoch+1}.pth'
        torch.save(generator.state_dict(), model_save_path)
        # with torch.no_grad():
        #     images_to_display = []
        #     for i, input_image in enumerate(test_loader):
        #         input_image = input_image[0].unsqueeze(0).to(device)  # Since test_loader only returns inputs
        #         cleaned_image = generator(input_image).cpu()
        #         images_to_display.append(cleaned_image)

        #         # Display only the first 5 cleaned images
        #         if i == 9:  # Display only 5 images
        #             break

        #     imshow(torch.cat(images_to_display), num_images=5)
# Out:
# Epoch [10/180], D Loss: 1.3193, G Loss: 0.9268
# Epoch [20/180], D Loss: 1.3132, G Loss: 0.8752
# Epoch [30/180], D Loss: 1.3763, G Loss: 0.9077
# Epoch [40/180], D Loss: 1.3295, G Loss: 0.8983
# Epoch [50/180], D Loss: 1.3281, G Loss: 0.9395
# Epoch [60/180], D Loss: 1.3380, G Loss: 0.8586
# Epoch [70/180], D Loss: 1.3623, G Loss: 0.7955
# Epoch [80/180], D Loss: 1.3881, G Loss: 0.8762
# Epoch [90/180], D Loss: 1.3993, G Loss: 0.8092
# Epoch [100/180], D Loss: 1.4091, G Loss: 0.7211
# Epoch [110/180], D Loss: 1.4415, G Loss: 0.7420
# Epoch [120/180], D Loss: 1.4250, G Loss: 0.7739
# Epoch [130/180], D Loss: 1.3629, G Loss: 0.7774
# Epoch [140/180], D Loss: 1.3521, G Loss: 0.7837
# Epoch [150/180], D Loss: 1.3950, G Loss: 0.7385
# Epoch [160/180], D Loss: 1.4041, G Loss: 0.7034
# Epoch [170/180], D Loss: 1.3406, G Loss: 0.7927
# Epoch [180/180], D Loss: 1.4025, G Loss: 0.8032

# %%
model_save_path = '/kaggle/working/gan_model_Final.pth'
torch.save(generator.state_dict(), model_save_path)

# %%
# Testing and saving cleaned images
generator.eval()
with torch.no_grad():
    for i, input_image in enumerate(test_loader):
        input_image = input_image.to(device)
        cleaned_image = generator(input_image)

        input_image = input_image.cpu().squeeze(0)
        cleaned_image = cleaned_image.cpu().squeeze(0)

        input_image_path = os.path.join(save_cleaned_path, f"input_{i + 1}.png")
        cleaned_image_path = os.path.join(save_cleaned_path, f"cleaned_{i + 1}.png")

        save_image(input_image, input_image_path)
        save_image(cleaned_image, cleaned_image_path)

print("Testing complete. Cleaned images saved.")
# Out:
# Testing complete. Cleaned images saved.

# %%
# !zip -r file.zip /kaggle/working/cleanedTestImages
# Out:
#   adding: kaggle/working/cleanedTestImages/ (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_105.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_84.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_170.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_23.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_294.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_1.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_99.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_178.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_35.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_169.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_68.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_6.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_230.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_74.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_290.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_288.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_98.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_234.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_111.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_119.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_242.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_26.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_283.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_121.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_206.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_153.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_63.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_76.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_259.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_162.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_142.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_151.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_28.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_86.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_3.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_162.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_40.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_35.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_44.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_166.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_105.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_206.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_273.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_192.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_107.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_14.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_65.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_270.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_205.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_91.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_194.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_194.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_245.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_141.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_160.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_191.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_75.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_30.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_58.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_63.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_147.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_213.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_66.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_195.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_300.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_267.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_204.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_144.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_76.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_116.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_77.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_115.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_284.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_219.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_102.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_102.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_268.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_175.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_188.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_285.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_253.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_127.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_279.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_205.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_82.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_292.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_293.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_218.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_16.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_241.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_264.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_131.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_129.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_234.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_122.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_180.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_25.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_113.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_124.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_11.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_171.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_31.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_30.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_149.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_260.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_34.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_96.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_36.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_48.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_266.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_249.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_68.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_98.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_41.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_246.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_39.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_128.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_156.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_44.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_131.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_33.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_282.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_46.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_240.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_7.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_55.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_84.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_70.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_197.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_274.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_57.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_101.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_90.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_124.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_299.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_166.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_61.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_114.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_132.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_222.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_72.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_207.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_134.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_295.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_237.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_149.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_261.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_80.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_109.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_51.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_32.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_254.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_86.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_147.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_117.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_38.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_284.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_255.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_53.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_155.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_163.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_212.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_244.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_223.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_43.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_156.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_161.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_263.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_252.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_67.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_25.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_164.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_9.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_186.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_120.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_126.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_47.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_5.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_255.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_50.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_247.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_56.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_154.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_159.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_79.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_104.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_24.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_66.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_138.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_12.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_289.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_278.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_222.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_174.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_22.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_236.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_150.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_100.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_202.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_243.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_87.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_128.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_275.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_269.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_28.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_180.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_33.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_202.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_238.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_204.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_244.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_145.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_18.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_228.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_88.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_34.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_135.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_165.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_168.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_152.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_227.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_197.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_65.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_27.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_154.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_45.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_93.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_203.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_224.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_193.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_273.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_3.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_103.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_73.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_104.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_201.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_267.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_114.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_152.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_6.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_106.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_137.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_188.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_77.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_164.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_262.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_223.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_286.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_292.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_8.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_88.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_109.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_239.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_81.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_133.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_253.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_221.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_161.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_254.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_183.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_210.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_271.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_64.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_274.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_90.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_11.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_228.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_268.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_118.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_39.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_78.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_263.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_42.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_135.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_16.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_60.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_265.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_82.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_101.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_191.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_265.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_225.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_285.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_139.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_113.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_52.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_54.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_20.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_271.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_129.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_211.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_130.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_4.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_294.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_227.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_236.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_196.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_283.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_229.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_140.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_295.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_89.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_14.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_123.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_241.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_94.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_167.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_117.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_298.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_282.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_2.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_118.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_21.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_15.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_297.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_221.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_276.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_281.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_81.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_29.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_251.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_212.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_242.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_258.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_181.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_125.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_287.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_199.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_36.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_17.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_89.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_92.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_238.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_296.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_69.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_133.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_122.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_232.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_286.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_163.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_127.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_123.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_278.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_220.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_297.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_198.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_138.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_47.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_23.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_115.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_108.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_72.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_148.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_21.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_59.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_106.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_4.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_289.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_179.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_79.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_160.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_22.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_208.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_87.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_136.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_42.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_146.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_119.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_49.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_201.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_150.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_168.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_256.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_64.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_277.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_24.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_78.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_7.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_80.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_287.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_61.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_246.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_143.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_32.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_159.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_184.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_233.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_299.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_215.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_158.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_177.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_187.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_37.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_62.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_91.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_257.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_157.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_245.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_276.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_93.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_291.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_52.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_208.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_176.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_200.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_185.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_55.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_239.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_29.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_218.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_112.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_207.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_174.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_215.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_217.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_144.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_216.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_233.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_177.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_290.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_99.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_139.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_261.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_141.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_211.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_190.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_185.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_250.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_110.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_250.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_231.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_10.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_178.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_71.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_176.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_54.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_70.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_8.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_220.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_67.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_182.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_248.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_226.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_209.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_195.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_256.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_165.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_296.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_243.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_279.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_300.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_157.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_120.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_137.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_148.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_73.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_198.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_1.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_12.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_172.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_229.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_95.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_48.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_95.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_130.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_262.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_240.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_237.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_275.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_5.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_280.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_280.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_59.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_193.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_18.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_199.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_171.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_181.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_173.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_277.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_136.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_103.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_2.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_209.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_100.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_20.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_40.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_31.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_146.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_213.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_71.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_110.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_281.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_27.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_19.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_210.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_75.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_121.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_50.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_235.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_192.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_186.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_203.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_96.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_19.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_179.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_216.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_94.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_9.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_259.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_62.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_126.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_13.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_116.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_46.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_167.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_190.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_134.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_125.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_247.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_226.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_49.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_92.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_184.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_85.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_291.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_252.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_272.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_214.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_251.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_51.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_56.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_158.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_58.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_140.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_175.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_189.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_45.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_231.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_224.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_189.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_272.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_107.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_43.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_230.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_235.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_57.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_132.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_219.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_232.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_264.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_153.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_143.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_97.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_112.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_111.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_85.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_293.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_298.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_13.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_200.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_38.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_17.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_37.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_170.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_151.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_258.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_288.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_10.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_217.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_196.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_108.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_187.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_173.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_15.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_214.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_60.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_182.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_142.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_145.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_269.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_53.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_172.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_41.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_155.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_257.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_97.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_83.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_169.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_266.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_248.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_183.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_83.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_26.png (stored 0%)
#   adding: kaggle/working/cleanedTestImages/input_225.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_249.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_270.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_74.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/input_69.png (deflated 0%)
#   adding: kaggle/working/cleanedTestImages/cleaned_260.png (deflated 0%)
